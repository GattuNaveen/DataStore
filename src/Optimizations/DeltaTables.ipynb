# %%
# %sql
DESCRIBE DETAIL datastore.gold.user

# %%
# %sql
DESCRIBE HISTORY datastore.gold.user;

# %%
# %sql
select * from datastore.gold.user version as of 22

# %%
# %sql
RESTORE TABLE datastore.gold.user VERSION AS OF 22

# %%
# %sql
RESTORE TABLE datastore.gold.user VERSION AS OF 26

# %%
# %sql
--SET spark.databricks.delta.retentionDurationCheck.enabled = false;
VACUUM datastore.gold.user DRY RUN RETAIN 0 HOURS

# %%
# %sql
Select * from datastore.gold.user

# %%
# %sql
ALTER TABLE datastore.gold.user
CLUSTER BY AUTO

# %%
# %sql

OPTIMIZE datastore.gold.user ZORDER BY (ExternalId)

# %%
from pyspark.sql.types import *
df = spark.createDataFrame([], StructType([]))
df.createTempView("Test")

# %%
# %sql
select * from Test
