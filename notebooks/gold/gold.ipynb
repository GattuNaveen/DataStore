# %%
# %sql
update datastore.bronze.user set name = 'abd' where id = 'f2e61887-3e12-4247-8e0b-2ee1a8580f28'

# %%
# %sql
select * from datastore.bronze.user where id = 'sdfghjkl'

# %%
# %sql
INSERT INTO datastore.bronze.user
SELECT * from datastore.bronze.user

# %%
# %sql
select *  from datastore.dlt_schema.gold_user where ExternalId  = 'f2e61887-3e12-4247-8e0b-2ee1a8580f28'

# %%
# %sql
drop table datastore.dlt_schema.bronze_user
