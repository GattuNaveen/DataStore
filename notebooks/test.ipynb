# %%
print("laxmi narasimha swamy")

# %%
# %sql
CREATE CATALOG IF NOT EXISTS DataStore COMMENT 'This is the new catalog used for this project'

# %%
# %sql
CREATE EXTERNAL VOLUME datastore.bronze.User
LOCATION "abfs"

# %%
# %sql
SHOW CATALOGS;
USE CATALOG datastore;
# %sql
SELECT current_catalog();

# %%
dbutils.fs.ls("abfss://source@datastorestorageaccount.dfs.core.windows.net/User/")

# %%
df = spark.read \
    .option("multiLine", "true") \
    .json("abfss://source@datastorestorageaccount.dfs.core.windows.net/User/users_001.json")

df.display()

# %%
display(df)
